# %%
import numpy as np
import matplotlib.pyplot as plt

import os
# %matplotlib inline

# %%
def openraw(filename, reshape=True):
    f = open(filename, 'rb')  #apre in binario
    rawdata = np.fromfile(f,dtype=np.uint16).astype(int)
    # 'H' = uint16
    # lo trovo in np.typeDict
    #legge in array i dati formattati uint16 e li casta ad int
    ''' NB è importantissimo castarli ad int:
        visto che sono numeri molto grandi, gli unsigned short non vanno bene (overflow) '''
    f.close
    if reshape:
        return rawdata.reshape((1234,1624))
    else:
        return rawdata

# %%
source = '/home/bec/stin/'
filelist = os.listdir(source)
imlist = [openraw(os.path.join(source, file), reshape=True) for file in filelist]
L = len(imlist)

kk = {'cmap': 'gray'}

# %%
[im.shape for im in imlist]
# Out:
# [(1234, 1624), (1234, 1624), (1234, 1624), (1234, 1624)]

# %%
for im in imlist:
    plt.figure()
    plt.imshow(im, cmap='gray')
    plt.colorbar()

# %%
OD = - np.log((im0+1)/(1+im1))
plt.imshow(im, **kk)
plt.colorbar()
