# %%
# %load_ext autoreload
# %pylab inline

from libraries import fileWatch
from libraries import params

import numpy as np

import matplotlib.pyplot as plt
from matplotlib.colorbar import make_axes
from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec

import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %autoreload 2

# %%
source = params.source
print(source)
# Out:
# /home/bec/stin/python

# %%
fileWatch.FWatch(source)
# Out:
# Osservo!
# /home/bec/stin/python/test-0000000000.ppm created
# New data:
# Wait for /home/bec/stin/python/test-0000000003.ppm
# /home/bec/stin/python/test-0000000001.ppm created
# New data:
# Wait for /home/bec/stin/python/test-0000000003.ppm
# /home/bec/stin/python/test-0000000002.ppm created
# New data:
# Wait for /home/bec/stin/python/test-0000000003.ppm
# /home/bec/stin/python/test-0000000003.ppm created
# New data:
# Processing!
# /home/bec/stin/python/test-0000000000.ppm
# /home/bec/stin/python/test-0000000001.ppm
# /home/bec/stin/python/test-0000000002.ppm
# /home/bec/stin/python/test-0000000003.ppm

# %%
from libraries import Sis2
import numpy as np

# %%
a = Sis2.readsis('mainTest.sis')[0]
# Out:
# You are opening the SisV2 file: mainTest.sis
# It says: 'Coriander-BEC3-mainTest...
# ...and was created on '2016-04-05 17:37:18'

# %%
imshow(a[:,:]*10/(2**16), cmap='gist_stern')
show()

# %%
b = a*10/(2**16)

# %%
b
# Out:
# array([[ 0.01190186,  9.99603271,  9.75097656, ...,  9.90737915,
#          0.20858765,  9.98626709],
#        [ 0.5128479 ,  0.20080566,  0.37139893, ...,  0.02471924,
#          0.38024902,  0.0680542 ],
#        [ 0.13641357,  9.8979187 ,  0.09033203, ...,  0.03540039,
#          9.71618652,  0.14221191],
#        ...,
#        [ 9.97314453,  0.14083862,  0.04867554, ...,  9.89868164,
#          9.87869263,  9.97879028],
#        [ 9.68994141,  0.0579834 ,  9.78485107, ...,  0.01068115,
#          0.01922607,  0.18264771],
#        [ 9.83230591,  9.9887085 ,  9.84466553, ...,  9.95346069,
#          0.10116577,  9.95697021]])

# %%
b.max()
# Out:
# 9.9981689453125

# %%
b.min()
# Out:
# 0.0

# %%
a
# Out:
# array([[   78, 65510, 63904, ..., 64929,  1367, 65446],
#        [ 3361,  1316,  2434, ...,   162,  2492,   446],
#        [  894, 64867,   592, ...,   232, 63676,   932],
#        ...,
#        [65360,   923,   319, ..., 64872, 64741, 65397],
#        [63504,   380, 64126, ...,    70,   126,  1197],
#        [64437, 65462, 64518, ..., 65231,   663, 65254]])

# %%
a.min()
# Out:
# 0

# %%
a.max()
# Out:
# 65524
