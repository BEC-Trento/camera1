# %%
# %load_ext autoreload
# %pylab inline

from libraries import fileWatch
from libraries import params

import numpy as np

import matplotlib.pyplot as plt
from matplotlib.colorbar import make_axes
from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec

import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %autoreload 2

# %%
source = params.source
print(source)
# Out:
# /var/abs/local/camera/python

# %%
fileWatch.FWatch(source)
# Out:
# Osservo!
# /var/abs/local/camera/python/test-0000000000.ppm created
# New data:
# Wait for /var/abs/local/camera/python/test-0000000003.ppm
# /var/abs/local/camera/python/test-0000000001.ppm created
# New data:
# Wait for /var/abs/local/camera/python/test-0000000003.ppm
# /var/abs/local/camera/python/test-0000000002.ppm created
# New data:
# Wait for /var/abs/local/camera/python/test-0000000003.ppm
# /var/abs/local/camera/python/test-0000000003.ppm created
# New data:
# Processing!
# /var/abs/local/camera/python/test-0000000000.ppm
# /var/abs/local/camera/python/test-0000000001.ppm
# /var/abs/local/camera/python/test-0000000002.ppm
# /var/abs/local/camera/python/test-0000000003.ppm
# [65535     1]

# %%
from libraries import Sis2
import numpy as np

# %%
a = Sis2.readsis('mainTest.sis')[0]
# Out:
# You are opening the SisV2 file: mainTest.sis
# It says: 'Coriander-BEC3-mainTest...
# ...and was created on '2016-04-08 12:11:08'

# %%
a
# Out:
# array([[ 6377,  7827,  7546, ...,  8385, 11583,  7402],
#        [ 8253,  9632,  7787, ..., 10483,  8811, 12485],
#        [ 8891, 10653,  9830, ...,  9368, 10367,  8283],
#        ...,
#        [ 8689,  8804,  8729, ...,  9582, 10010,  8346],
#        [ 8988,  9431,  8946, ..., 10793,  8543,  7706],
#        [ 8931,  7420,  9607, ...,  8537,  9372,  8361]])

# %%
imshow(a,interpolation='none', cmap='gist_stern')
show()
